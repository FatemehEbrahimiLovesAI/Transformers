# %%
from transformers import pipeline

# %%
unmasker = pipeline('fill-mask')
unmasker('Hello Mr. Frank! My Name is <mask>. Nice to meet you.',top_k=2)
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /distilbert/distilroberta-base/resolve/fb53ab8/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: d0e1873e-dc47-4f9d-8b81-d431addab068)')' thrown while requesting HEAD https://huggingface.co/distilbert/distilroberta-base/resolve/fb53ab8/config.json
# Retrying in 1s [Retry 1/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /distilbert/distilroberta-base/resolve/fb53ab8/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 1ec64613-a3e3-432e-b81a-6ec116e451ce)')' thrown while requesting HEAD https://huggingface.co/distilbert/distilroberta-base/resolve/fb53ab8/config.json
# Retrying in 2s [Retry 2/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /distilbert/distilroberta-base/resolve/fb53ab8/config.json (Caused by NameResolutionError("HTTPSConnection(host=\'huggingface.co\', port=443): Failed to resolve \'huggingface.co\' ([Errno 11001] getaddrinfo failed)"))'), '(Request ID: 0ce76c67-5600-48ff-8d82-449b6e6dcf8b)')' thrown while requesting HEAD https://huggingface.co/distilbert/distilroberta-base/resolve/fb53ab8/config.json
# Retrying in 4s [Retry 3/5].
# '(MaxRetryError("HTTPSConnectionPool(host='huggingface.co', port=443): Max retries exceeded with url: /distilbert/distilroberta-base/resolve/fb53ab8/config.json (Caused by ConnectTimeoutError(<HTTPSConnection(host='huggingface.co', port=443) at 0x20787c0a370>, 'Connection to huggingface.co timed out. (connect timeout=10)'))"), '(Request ID: f9476c57-aedb-4d4d-bbd7-e8d2754ab4bb)')' thrown while requesting HEAD https://huggingface.co/distilbert/distilroberta-base/resolve/fb53ab8/config.json
# Retrying in 8s [Retry 4/5].
# WARNING:tensorflow:From c:\Users\pc\.conda\envs\ai\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
